# %% [markdown]
# ### 한국어 형태소 분석기 Spacy
# - 빠른 속도와 정확도가 높은 형태소 분석기
# - 설치 2단계
#     - 형태소 분석기 설치
#     - 언어별 모델 설치

# %%
import spacy
from IPython.display import SVG

# %%
# Korean lang model
KO_MODEL = 'ko_core_news_sm'

# %%
nlp = spacy.load(KO_MODEL)

# %%
text = '내일 스터디는 기대가 됩니다.'
doc = nlp(text)

for token in doc:
    # 표제어, 단어 품사, 자세한 품사, 불용어 여부
    print(f"{token.text:6} {token.lemma_:6} {token.pos_:6} {token.tag_:6} {token.is_stop:6}")
# Out:
# 내일     내일     NOUN   ncn         0
# 스터디는   스터디+는  ADV    nq+jca      0
# 기대가    기대+가   NOUN   ncpa+jcs      0
# 됩니다    되+ㅂ니다  VERB   pvg+ef      0
# .      .      PUNCT  sf          0

# %%
text = """
누구와 먹고 살지
나와 먹고 살지

누구의 손을 잡지
나의 손을 잡지

아직은 아니되오
지금은 할 수 없어

어서 내 손을 잡아
함께 가자

혼인하자
"""
doc = nlp(text)

for token in doc:
    if token.tag_ != '_SP':
        print(f"{token.text:6}  {token.lemma_:6}    {token.pos_:6}  {token.tag_:6}  {token.is_stop:1}")
# Out:
# 누구와     누구+와      CCONJ   npp+jct  0
# 먹고      먹+고       SCONJ   pvg+ecs  0
# 살지      살+지       VERB    pvg+etm  0
# 나와      나오+아      SCONJ   npp+jct  0
# 먹고      먹+고       SCONJ   pvg+ecc  0
# 살지      살+지       VERB    pvg+etm  0
# 누구의     누구+의      PRON    npp+jcm  0
# 손을      손+을       NOUN    ncn+jco  0
# 잡지      잡지        VERB    pvg+etm  0
# 나의      나+의       PRON    npp+jcm  0
# 손을      손+을       NOUN    ncn+jco  0
# 잡지      잡지        NOUN    ncn     0
# 아직은     아직+은      NOUN    npp+jxt  0
# 아니되오    아니되+오     VERB    ncn+jp+ef  0
# 지금은     지금+은      NOUN    ncn+jxt  0
# 할       하+ㄹ       VERB    pvg+etm  0
# 수       수         NOUN    nbn     1
# 없어      없+어       SCONJ   paa+ecs  0
# 어서      어서        PRON    npp+jco  0
# 내       내         PRON    npp     0
# 손을      손+을       NOUN    ncn+jco  0
# 잡아      잡+아       VERB    pvg+ecx  0
# 함께      함께        ADV     mag     0
# 가자      가자        NOUN    ncn     0
# 혼인하자    혼인+하+자    SCONJ   ncpa+jp+ecs  0

# %%
my_tokens = []

for token in doc:
    if (not token.is_stop) and (token.pos_!='SPACE'):
        my_tokens.append(token)

# %%
my_tokens
# Out:
# [누구와,
#  먹고,
#  살지,
#  나와,
#  먹고,
#  살지,
#  누구의,
#  손을,
#  잡지,
#  나의,
#  손을,
#  잡지,
#  아직은,
#  아니되오,
#  지금은,
#  할,
#  없어,
#  어서,
#  내,
#  손을,
#  잡아,
#  함께,
#  가자,
#  혼인하자]

# %% [markdown]
# - for token in doc: 에서 볼 수 있는 속성들
# ---
# - .text: 저장된 텍스트
# - .lemma_: 표제어 속성
# - .pos_: 품사 속성
# - .tag_: 상세 품사 속성
# - .is_stop: 불용어 여부 속성
# - .is_punct: 구두점 여부 속성

# %%
text = """
놀자 놀자 마저 놀자
긴밤 건너 내가 왔어
두 눈 밝게 뜨고
길고 하얀 기억쥐고

문 앞까지 다다른
흉내쟁이가
내가 왔어
내가 돌아 왔어

에헤야히야
즐겁게 놀아보자
에헤야히야
혀 위에서 놀자

이 목소리는
지나칠 수 없을 테니
어서 그 문을 열어줘
"""
doc = nlp(text)

for token in doc:
    if token.tag_ != '_SP':
        print(f"{token.text:6}  {token.lemma_:6}    {token.pos_:6}  {token.tag_:6}  {token.is_stop:1}")
# Out:
# 놀자      놀자        SCONJ   pvg+ecs  0
# 놀자      놀자        AUX     pvg+ecx+px+etm  0
# 마저      마저        NOUN    ncn     0
# 놀자      놀자        VERB    pvg+etm  0
# 긴밤      긴+밤       ADV     ncpa    0
# 건너      건너+어      SCONJ   pvg+ecs  0
# 내가      내+가       PRON    npp+jcs  0
# 왔어      왔어        NOUN    pvg+etm  0
# 두       두         NUM     nnc     1
# 눈       눈         NOUN    ncn     0
# 밝게      밝+게       SCONJ   paa+ecs  0
# 뜨고      뜨+고       CCONJ   pvg+ecc  0
# 길고      길+고       CCONJ   paa+ecc  0
# 하얀      하얗+ㄴ      ADJ     paa+etm  0
# 기억쥐고    기억쥐고      ADV     ncn+ncn+xsn+jp+etm  0
# 문       문         NOUN    ncn     0
# 앞까지     앞까+지      NOUN    ncn+jcm  0
# 다다른     다다른       VERB    paa+etm  0
# 흉내쟁이가   흉내쟁이+가    CCONJ   nq+jct  0
# 내가      내+가       PRON    npp+jcs  0
# 왔어      왔어        VERB    pvg+etm  0
# 내가      내+가       PRON    npp+jcs  0
# 돌아      돌아        SCONJ   pvg+ecs  0
# 왔어      오+았+어     NOUN    pvg+etm  0
# 에헤야히야   에헤야+히야    PROPN   ncn+jcj  0
# 즐겁게     즐겁+게      SCONJ   paa+ecs  0
# 놀아보자    놀아+보자     ADV     ncn+jcm  0
# 에헤야히야   에헤야+히야    PROPN   nq      0
# 혀       혀         NOUN    ncn     0
# 위에서     위+에서      ADV     ncn+jca  0
# 놀자      놀자        SCONJ   pvg+etm  0
# 이       이         DET     mmd     1
# 목소리는    목소리+는     NOUN    ncn+jxt  0
# 지나칠     지나치+ㄹ     VERB    pvg+etm  0
# 수       수         NOUN    nbn     1
# 없을      없+ㄹ       ADJ     paa+etm  0
# 테니      테니        SCONJ   nbn+jp+ecs  0
# 어서      어서        NOUN    ncn     0
# 그       그         DET     mmd     1
# 문을      문+을       NOUN    ncn+jco  0
# 열어줘     열어줘       VERB    pvg+ep+ef  0

# %%
text = """
나비 여럿 날아간다 구름바다 넘실댄다
땀방울 튀어가매 멀리멀리 노닌다
바람 하나 파도 되어 나무 하나 사이에 끼고
온 천하 제 것인양 촐싹대면서 퍼런 하늘로 간다

너른 벌은 강을 끼고
작은 강은 숲을 끼고
겹겹이 쌓이며 휘돌아 춤을 춘다
새 한 마리 날에 취해 뻐꾹 뻐꾹
주사를 벌이다가 남은 이슬을 낚아채고서 간다

쇳빛 하늘 우중충하다 잎새들 서로 엉켜가니
논벼들은 다 고개 드매 서로 밀치며 쓰러지니
먹구름 떼가 몰려오고 바람이 포악해져가고
빗방울 후둑 떨어지고 천둥번개가 내리쳐온다

하얀 불이여 내 안에 깃드오
세상에 흐르는 저 물길처럼
들바람이여 나를 태워주오
이 몸이 한 줌 흙이 되도록

구름 사이 햇살 하나 고개 밀어 내비친다
얼룩진 바위들은 다물던 입을 연다
물안개가 질 즈음에 젖은 풀잎이 고개 든다
소나기 더 몰려와 폭포 위에서 맹렬히 퍼붓는다

비가 내려 홍수난다 햇살 내려 가뭄난다
하늘의 창날은 결국엔 무디노라
잿빛 하늘 시드노니 태풍이 온다
물난리 벌어지며 모두 쓸려가 민둥산으로 간다

한 백년은 일 년과 같고 한 일년은 하루와 같고
하루가 지금 끝나가매 동산에 무지개가 뜨니
잔해들 모두 거두고서 노을 아래서 만나리라
아침을 여는 빛은 지금 저녁을 향해 날아가노라

하얀 불이여 내 안에 깃드오
세상에 흐르는 저 물길처럼
들바람이여 나를 태워주오
이 몸이 한 줌 흙이 되도록

하늘의 빛에 태어나고
하늘의 삶을 살아가고
땅의 온기에 뼈를 묻어 지노라

새 아침이 환히 열리면
나는 한 명의 사람으로서
태어나리라
"""
doc = nlp(text)

for token in doc:
    if token.tag_ != '_SP':
        print(f"{token.text:6}  {token.lemma_:6}    {token.pos_:6}  {token.tag_:6}  {token.is_stop:1}")
# Out:
# 나비      나+비       VERB    pvg+etm  0
# 여럿      여럿        NUM     nnc     0
# 날아간다    날아간+다     NOUN    ncn+jco  0
# 구름바다    구+름바+다    ADV     ncpa+ncpa+jca  0
# 넘실댄다    넘실댄+다     VERB    pvg+etm  0
# 땀방울     땀방+울      ADV     ncn+jca  0
# 튀어가매    튀+어+가+매    CCONJ   ncpa+xsn+jp+ecc  0
# 멀리멀리    멀+리+멀+리    VERB    px+ef+jcr  0
# 노닌다     +노+닌다     CCONJ   ncpa+xsv+ecc  0
# 바람      바람        NOUN    ncn     0
# 하나      하나        NUM     nnc     1
# 파도      파+도       NOUN    pvg+ecx  0
# 되어      되+어       SCONJ   pvg+ecs  0
# 나무      나무        NOUN    ncn     0
# 하나      하나        NUM     nnc     1
# 사이에     사이+에      ADV     ncn+jca  0
# 끼고      끼+고       VERB    pvg+ef  0
# 온       오+ㄴ       VERB    px+etm  0
# 천하      천하        NOUN    ncn     0
# 제       제         PRON    mma     0
# 것인양     것+인양      ADV     nbn+jca  0
# 촐싹대면서   촐싹대면+서    NOUN    ncn+jco  0
# 퍼런      퍼+런       SCONJ   pvg+ecs  0
# 하늘로     하늘+로      ADV     ncn+jca  0
# 간다      가+ㄴ다      VERB    pvg+etm  0
# 너른      너른        NOUN    ncn     0
# 벌은      벌+은       VERB    ncn+jcm  0
# 강을      강+을       NOUN    ncps+jco  0
# 끼고      끼+고       SCONJ   pvg+ecc  0
# 작은      작+ㄴ       ADJ     paa+etm  0
# 강은      강+은       NOUN    ncn+jxt  0
# 숲을      숲+을       NOUN    ncn+jco  0
# 끼고      끼+고       VERB    pvg+ecc  0
# 겹겹이     겹겹이       ADV     mag     0
# 쌓이며     쌓+이며      SCONJ   pvg+ecs  0
# 휘돌아     휘돌+아      SCONJ   pvg+ecs  0
# 춤을      춤+을       NOUN    ncn+jco  0
# 춘다      춘다        VERB    pvg+ef  0
# 새       새         ADJ     mma     0
# 한       한         NUM     nnc     1
# 마리      마리        NOUN    nbu     0
# 날에      날+에       ADV     ncn+jca  0
# 취해      취하+어      SCONJ   pvg+ecs  0
# 뻐꾹      뻐+꾹       CCONJ   ncn+jcj  0
# 뻐꾹      뻐꾹        VERB    pvg+etn  0
# 주사를     주사+를      NOUN    ncn+jxt  0
# 벌이다가    벌이다+가     ADV     ncn+jca  0
# 남은      남+ㄴ       VERB    pvg+etm  0
# 이슬을     이슬+을      NOUN    ncn+jcm  0
# 낚아채고서   낚아채고+이+서    VERB    nq+jp+etm  0
# 간다      가+ㄴ다      SCONJ   nnc     0
# 쇳빛      쇳빛        NOUN    ncn     0
# 하늘      하늘        NOUN    ncn     0
# 우중충하다   우중충+하다    NOUN    ncn+ncn+jcs  0
# 잎새들     잎+새들      NOUN    ncpa+jco  0
# 서로      서로        ADV     mag     0
# 엉켜가니    엉켜가니      VERB    pvg+ep+ecs  0
# 논벼들은    논+벼들+은    ADV     ncn+jca  0
# 다       다         ADV     mag     0
# 고개      고개        NOUN    ncn     0
# 드매      드+매       CCONJ   pvg+ecc  0
# 서로      서로        ADV     mag     0
# 밀치며     밀치+며      ADV     pvg+ecs  0
# 쓰러지니    쓰러+지니     VERB    pvg+etm  0
# 먹구름     먹구름       SCONJ   pvg+ecs  0
# 떼가      떼가        NOUN    ncn     0
# 몰려오고    몰려오고      AUX     pvg+ecx+px+etm  0
# 바람이     바람+이      NOUN    ncn+jcs  0
# 포악해져가고  포악해져+가+고    CCONJ   ncpa+xsv+ecc  0
# 빗방울     빗방울       PROPN   nq      0
# 후둑      후+둑       ADV     ncn+jca  0
# 떨어지고    떨어지+고     CCONJ   pvg+ecc  0
# 천둥번개가   천둥번+개+가    NUM     nnc+nbu+jcs  0
# 내리쳐온다   내리쳐+온다    NOUN    ncn+jco  0
# 하얀      하얗+ㄴ      ADJ     paa+etm  0
# 불이여     불이+여      NOUN    ncn+jxt  0
# 내       내         PRON    npp     0
# 안에      안+에       ADV     ncn+jca  0
# 깃드오     깃드+오      NOUN    ncn+xsn  0
# 세상에     세상+에      ADV     ncn+jca  0
# 흐르는     흐르+는      VERB    pvg+etm  0
# 저       저         PRON    npp     0
# 물길처럼    물길처럼      NOUN    ncn     0
# 들바람이여   들바람이여     CCONJ   pvg+ecs+jxc  0
# 나를      나+를       PRON    npp+jco  0
# 태워주오    태워+주+오    VERB    pvg+ep+etm  0
# 이       이         DET     mmd     1
# 몸이      몸+이       NOUN    ncn+jcs  0
# 한       한         VERB    pvg+etm  1
# 줌       줌         NOUN    ncn     0
# 흙이      흙+이       NOUN    ncn+jcs  0
# 되도록     되+도록      SCONJ   pvg+ecs  0
# 구름      구름        NOUN    ncn     0
# 사이      사이        NOUN    ncn     0
# 햇살      햇살        NOUN    ncn     0
# 하나      하나        NUM     nnc     1
# 고개      고개        NOUN    ncn     0
# 밀어      밀+어       SCONJ   pvg+ecs  0
# 내비친다    내비친다      AUX     pvg+ecx+px+etm  0
# 얼룩진     얼룩+진      VERB    ncn+jcm  0
# 바위들은    바위들+은     NOUN    ncn+jco  0
# 다물던     다물+던      CCONJ   pvg+ecc  0
# 입을      입+을       NOUN    ncn+jco  0
# 연다      연다        SCONJ   ncpa    0
# 물안개가    물안개+가     NOUN    ncn+jco  0
# 질       질         VERB    pvg+etm  0
# 즈음에     즈+이+음에    SCONJ   pvg+ecs  0
# 젖은      젖+ㄴ       VERB    pvg+etm  0
# 풀잎이     풀잎+이      NOUN    ncn+jco  0
# 고개      고개        NOUN    ncn     0
# 든다      든다        VERB    ncpa    0
# 소나기     소나+기      NOUN    pvg+ecc  0
# 더       더         ADV     mag     1
# 몰려와     몰려와       VERB    ncpa+xsv+etm  0
# 폭포      폭포        NOUN    ncn     0
# 위에서     위+에서      ADV     ncn+jca  0
# 맹렬히     맹렬히       CCONJ   ncpa+xsv+etm  0
# 퍼붓는다    퍼붓는다      ADV     ncn+jca  0
# 비가      비+가       NOUN    ncn+jcs  0
# 내려      내리+어      SCONJ   pvg+ecs  0
# 홍수난다    홍수난+다     NOUN    ncn+jco  0
# 햇살      햇살        NOUN    ncn     0
# 내려      내리+어      SCONJ   pvg+ecs  0
# 가뭄난다    가뭄난다      NOUN    ncn     0
# 하늘의     하늘+의      NOUN    ncn+jcm  0
# 창날은     창날+은      ADV     ncpa+jcs  0
# 결국엔     결국엔       NOUN    ncn+jcs  0
# 무디노라    무디노라      NOUN    ncn+jxc+jco  0
# 잿빛      잿빛        NOUN    ncn     0
# 하늘      하늘        NOUN    ncn     0
# 시드노니    시드+노니     ADV     ncn+jca  0
# 태풍이     태풍+이      NOUN    ncn+jcs  0
# 온다      오+ㄴ다      VERB    pvg+etm  0
# 물난리     물난+리      NOUN    ncn+ncn  0
# 벌어지며    벌+어지+며    NOUN    ncn+ncn+jxt  0
# 모두      모두        NOUN    mag     0
# 쓸려가     쓸려+가      NOUN    ncn+jco  0
# 민둥산으로   민둥산+으로    ADV     nq+jca  0
# 간다      가+ㄴ다      VERB    pvg+ef  0
# 한       한         NUM     nnc     1
# 백년은     백+년은      ADV     ncn+jp+etm  0
# 일       일         NUM     nnc     1
# 년과      년+과       CCONJ   nbu+jct  0
# 같고      같+고       CCONJ   paa+ecc  0
# 한       한         NUM     nnc     1
# 일년은     일년+은      NOUN    nq+jcs  0
# 하루와     하루+와      PROPN   nq+jcm  0
# 같고      같+고       CCONJ   paa+ecc  0
# 하루가     하루+가      NOUN    ncn+jcs  0
# 지금      지금        NOUN    ncn     0
# 끝나가매    끝나가+매     NOUN    pvg+ecs  0
# 동산에     동산+에      NOUN    ncn+jcs  0
# 무지개가    무지개+가     NOUN    ncn+jco  0
# 뜨니      뜨+니       SCONJ   pvg+ecs  0
# 잔해들     잔+해들      CCONJ   ncn+jca  0
# 모두      모두        ADV     mag     0
# 거두고서    거두고서      VERB    pvg+etm  0
# 노을      노을        NOUN    ncn     0
# 아래서     아래+서      ADV     ncn+jca  0
# 만나리라    만나리+라     CCONJ   pvg+ecc  0
# 아침을     아침+을      NOUN    ncn+jco  0
# 여는      열+는       VERB    pvg+etm  0
# 빛은      빛+은       NOUN    ncn+jxt  0
# 지금      지금        NOUN    ncn     0
# 저녁을     저녁+을      NOUN    ncn+jco  0
# 향해      향하+어      SCONJ   pvg+ecs  0
# 날아가노라   날아가+노라    VERB    pvg+ep+etm  0
# 하얀      하얗+ㄴ      ADJ     paa+etm  0
# 불이여     불이+여      NOUN    ncn+jxt  0
# 내       내         PRON    npp     0
# 안에      안+에       ADV     ncn+jca  0
# 깃드오     깃드+오      NOUN    ncn+xsn  0
# 세상에     세상+에      ADV     ncn+jca  0
# 흐르는     흐르+는      VERB    pvg+etm  0
# 저       저         PRON    npp     0
# 물길처럼    물길처럼      NOUN    ncn     0
# 들바람이여   들바람이여     CCONJ   pvg+ecs+jxc  0
# 나를      나+를       PRON    npp+jco  0
# 태워주오    태워+주+오    VERB    pvg+ep+etm  0
# 이       이         DET     mmd     1
# 몸이      몸+이       NOUN    ncn+jcs  0
# 한       한         VERB    pvg+etm  1
# 줌       줌         NOUN    ncn     0
# 흙이      흙+이       NOUN    ncn+jcs  0
# 되도록     되+도록      SCONJ   pvg+ecs  0
# 하늘의     하늘+의      NOUN    ncn+jcm  0
# 빛에      빛+에       ADV     ncn+jca  0
# 태어나고    태어나+고     CCONJ   pvg+ecc  0
# 하늘의     하늘+의      NOUN    ncn+jcm  0
# 삶을      삶+을       NOUN    ncn+jco  0
# 살아가고    살+아+가+고    AUX     pvg+ecx+px+ecc  0
# 땅의      땅+의       NOUN    ncn+jcm  0
# 온기에     온기에       VERB    ncn+jp+etm  0
# 뼈를      뼈+를       NOUN    ncn+jco  0
# 묻어      묻+어       CCONJ   pvg+ecc  0
# 지노라     지노+라      SCONJ   pvg+ecs  0
# 새       새         ADJ     mma     0
# 아침이     아침+이      NOUN    ncn+jcm  0
# 환히      환히        NOUN    ncn+jco  0
# 열리면     열리면       VERB    pvg+ep+ef  0
# 나는      나+는       PRON    npp+jxt  0
# 한       한         NUM     mma     1
# 명의      명+의       NOUN    nbu+jcm  0
# 사람으로서   사람+으로서    ADV     ncn+jca  0
# 태어나리라   태어나리+라    VERB    pvg+etn  0

# %%
SVG(spacy.displacy.render(doc))
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ko" id="d5948300fea54598b67a44ad334ad69d-0" class="displacy" width="6175" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">누구와</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">먹고</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">살지</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">나와</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">먹고</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">살지</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">누구의</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">손을</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">잡지</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">나의</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">손을</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">잡지</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">아직은</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">아니되오</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">지금은</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">할</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">수</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">없어</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">어서</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">내</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">손을</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">잡아</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">함께</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="c
